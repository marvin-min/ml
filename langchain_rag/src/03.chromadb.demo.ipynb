# %%
import chromadb

# %%
client = chromadb.Client()
collection = client.get_or_create_collection(name="my_rag")

# %%
collection.upsert(
    documents=[
        "This is a document about pineapple",
        "This is a document about oranges"
    ],
    ids=["id1", "id2"]
)

# %%
results = collection.query(
    query_texts=["This is a query document about florida"], # Chroma will embed this for you
    n_results=2 # how many results to return
)
results
# Out:
# {'ids': [['id2', 'id1']],
#  'distances': [[1.146208643913269, 1.301512360572815]],
#  'metadatas': [[None, None]],
#  'embeddings': None,
#  'documents': [['This is a document about oranges',
#    'This is a document about pineapple']],
#  'uris': None,
#  'data': None}

# %%
import chromadb.utils.embedding_functions as embedding_functions

# %%
ollama_ef = embedding_functions.OllamaEmbeddingFunction(
  url="http://127.0.0.1:11434/api/embeddings",
   model_name="llama3",
)

# %%
embeddings = ollama_ef(["This is my first text to embed",
                        "This is my second document"])

# %%
print(embeddings)
# Out:
# [[0.1833133101463318, -3.9996042251586914, 2.2343130111694336, -1.3242229223251343, 2.5273940563201904, -1.1715961694717407, 5.870514392852783, 0.5390788316726685, 1.6295338869094849, 0.6192649006843567, 3.224228620529175, 2.6721839904785156, -2.1592276096343994, -0.0029623378068208694, -1.7974069118499756, 1.676993489265442, -2.9550418853759766, 3.6096913814544678, -3.6704912185668945, 3.1779236793518066, -1.2349529266357422, -0.3245771527290344, 3.333568572998047, -0.5301775336265564, -0.8836503624916077, 0.910510241985321, 2.782587766647339, -0.7462895512580872, 0.5043508410453796, -3.1886062622070312, -0.19488447904586792, 2.682305335998535, 1.3207530975341797, 1.5589734315872192, 4.9727559089660645, 3.415710210800171, 0.11508940905332565, -0.18507477641105652, 0.7956389784812927, 1.248953104019165, 1.3858592510223389, -0.9834052920341492, 4.150599956512451, -0.8077879548072815, 1.0305405855178833, -0.41568368673324585, 2.326218605041504, -2.964413642883301, 2.2337563037872314, -2.6890690326690674, -0.11945956200361252, -0.3661021888256073, 2.314600944519043, 2.4644615650177, 0.1972583830356598, 2.352597713470459, -1.361236810684204, -0.4793936610221863, -3.3299713134765625, 2.495417594909668, -2.3858094215393066, 1.6150317192077637, 3.3694069385528564, -4.031619071960449, 1.2531198263168335, 0.36273446679115295, -3.5325748920440674, -1.4122358560562134, 1.0031527280807495, 3.8465023040771484, 1.52882719039917, -0.1203974112868309, 5.767282485961914, -0.4416136145591736, 0.3015899062156677, 3.0983388423